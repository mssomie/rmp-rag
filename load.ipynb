# %%
from dotenv import load_dotenv
load_dotenv()
import os
from groq import Groq
from openai import OpenAI
from pinecone import Pinecone, ServerlessSpec
from sentence_transformers import SentenceTransformer
import json

# %%
pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))
pc.create_index(
    name="rmp-rag", dimension = 1024, metric = "cosine", spec=ServerlessSpec(cloud="aws", region="us-east-1")
)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/urllib3/connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File /opt/anaconda3/envs/rag/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))
# ----> 2 pc.create_index(
#       3     name="rmp-rag", dimension = 1024, metric = "cosine", spec=ServerlessSpec(cloud="aws", region="us-east-1")
#       4 )
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/pinecone/control/pinecone.py:384, in Pinecone.create_index(self, name, dimension, spec, metric, timeout, deletion_protection)
#     381 else:
#     382     raise TypeError("spec must be of type dict, ServerlessSpec, or PodSpec")
# --> 384 api_instance.create_index(
#     385     create_index_request=CreateIndexRequest(
#     386         name=name,
#     387         dimension=dimension,
#     388         metric=metric,
#     389         spec=index_spec,
#     390         deletion_protection=dp,
#     391     ),
#     392 )
#     394 def is_ready():
#     395     status = self._get_status(name)
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:761, in Endpoint.__call__(self, *args, **kwargs)
#     750 def __call__(self, *args, **kwargs):
#     751     """This method is invoked when endpoints are called
#     752     Example:
#     753
#    (...)
#     759
#     760     """
# --> 761     return self.callable(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/control/api/manage_indexes_api.py:273, in ManageIndexesApi.__init__.<locals>.__create_index(self, create_index_request, **kwargs)
#     271 kwargs["_host_index"] = kwargs.get("_host_index")
#     272 kwargs["create_index_request"] = create_index_request
# --> 273 return self.call_with_http_info(**kwargs)
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:819, in Endpoint.call_with_http_info(self, **kwargs)
#     816     header_list = self.api_client.select_header_content_type(content_type_headers_list)
#     817     params["header"]["Content-Type"] = header_list
# --> 819 return self.api_client.call_api(
#     820     self.settings["endpoint_path"],
#     821     self.settings["http_method"],
#     822     params["path"],
#     823     params["query"],
#     824     params["header"],
#     825     body=params["body"],
#     826     post_params=params["form"],
#     827     files=params["file"],
#     828     response_type=self.settings["response_type"],
#     829     auth_settings=self.settings["auth"],
#     830     async_req=kwargs["async_req"],
#     831     _check_type=kwargs["_check_return_type"],
#     832     _return_http_data_only=kwargs["_return_http_data_only"],
#     833     _preload_content=kwargs["_preload_content"],
#     834     _request_timeout=kwargs["_request_timeout"],
#     835     _host=_host,
#     836     collection_formats=params["collection_format"],
#     837 )
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:380, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     326 """Makes the HTTP request (synchronous) and returns deserialized data.
#     327
#     328 To make an async_req request, set the async_req parameter.
#    (...)
#     377     then the method will return the response directly.
#     378 """
#     379 if not async_req:
# --> 380     return self.__call_api(
#     381         resource_path,
#     382         method,
#     383         path_params,
#     384         query_params,
#     385         header_params,
#     386         body,
#     387         post_params,
#     388         files,
#     389         response_type,
#     390         auth_settings,
#     391         _return_http_data_only,
#     392         collection_formats,
#     393         _preload_content,
#     394         _request_timeout,
#     395         _host,
#     396         _check_type,
#     397     )
#     399 return self.pool.apply_async(
#     400     self.__call_api,
#     401     (
#    (...)
#     418     ),
#     419 )
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:175, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     171     url = _host + resource_path
#     173 try:
#     174     # perform request and return response
# --> 175     response_data = self.request(
#     176         method,
#     177         url,
#     178         query_params=query_params,
#     179         headers=header_params,
#     180         post_params=post_params,
#     181         body=body,
#     182         _preload_content=_preload_content,
#     183         _request_timeout=_request_timeout,
#     184     )
#     185 except PineconeApiException as e:
#     186     e.body = e.body.decode("utf-8")
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:460, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     450     return self.rest_client.OPTIONS(
#     451         url,
#     452         query_params=query_params,
#    (...)
#     457         body=body,
#     458     )
#     459 elif method == "POST":
# --> 460     return self.rest_client.POST(
#     461         url,
#     462         query_params=query_params,
#     463         headers=headers,
#     464         post_params=post_params,
#     465         _preload_content=_preload_content,
#     466         _request_timeout=_request_timeout,
#     467         body=body,
#     468     )
#     469 elif method == "PUT":
#     470     return self.rest_client.PUT(
#     471         url,
#     472         query_params=query_params,
#    (...)
#     477         body=body,
#     478     )
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/rest.py:345, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     335 def POST(
#     336     self,
#     337     url,
#    (...)
#     343     _request_timeout=None,
#     344 ):
# --> 345     return self.request(
#     346         "POST",
#     347         url,
#     348         headers=headers,
#     349         query_params=query_params,
#     350         post_params=post_params,
#     351         _preload_content=_preload_content,
#     352         _request_timeout=_request_timeout,
#     353         body=body,
#     354     )
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/rest.py:190, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     188     if body is not None:
#     189         request_body = json.dumps(body)
# --> 190     r = self.pool_manager.request(
#     191         method,
#     192         url,
#     193         body=request_body,
#     194         preload_content=_preload_content,
#     195         timeout=timeout,
#     196         headers=headers,
#     197     )
#     198 elif headers["Content-Type"] == "application/x-www-form-urlencoded":  # noqa: E501
#     199     r = self.pool_manager.request(
#     200         method,
#     201         url,
#    (...)
#     206         headers=headers,
#     207     )
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/urllib3/_request_methods.py:144, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     136     return self.request_encode_url(
#     137         method,
#     138         url,
#    (...)
#     141         **urlopen_kw,
#     142     )
#     143 else:
# --> 144     return self.request_encode_body(
#     145         method, url, fields=fields, headers=headers, **urlopen_kw
#     146     )
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/urllib3/_request_methods.py:279, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     275     extra_kw["headers"].setdefault("Content-Type", content_type)
#     277 extra_kw.update(urlopen_kw)
# --> 279 return self.urlopen(method, url, **extra_kw)
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/urllib3/poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/urllib3/connection.py:615, in HTTPSConnection.connect(self)
#     613 def connect(self) -> None:
#     614     sock: socket.socket | ssl.SSLSocket
# --> 615     self.sock = sock = self._new_conn()
#     616     server_hostname: str = self.host
#     617     tls_in_tls = False
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/urllib3/connection.py:196, in HTTPConnection._new_conn(self)
#     191 """Establish a socket connection and set nodelay settings on it.
#     192
#     193 :return: New socket connection.
#     194 """
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#     203     raise NameResolutionError(self.host, self, e) from e
#
# KeyboardInterrupt:

# %%
import json
data=json.load(open("reviews.json"))
data["reviews"]
# Out:
# [{'professor': 'Dr. Emily Johnson',
#   'subject': 'Introduction to Psychology',
#   'stars': 5,
#   'review': 'Dr. Johnson is an amazing professor! Her lectures are engaging, and she genuinely cares about her students.'},
#  {'professor': 'Professor Michael Lee',
#   'subject': 'Calculus I',
#   'stars': 4,
#   'review': 'Great professor, but the material can be tough. He explains concepts well, though you need to put in the effort.'},
#  {'professor': 'Dr. Sarah Thompson',
#   'subject': 'Organic Chemistry',
#   'stars': 3,
#   'review': 'Dr. Thompson knows her stuff, but her exams are really challenging. Be prepared to study hard.'},
#  {'professor': 'Professor James Harris',
#   'subject': 'World History',
#   'stars': 2,
#   'review': 'Lectures are a bit dry, and the grading is tough. Not my favorite class.'},
#  {'professor': 'Dr. Laura Martinez',
#   'subject': 'Introduction to Sociology',
#   'stars': 5,
#   'review': 'Dr. Martinez is incredible! She makes complex topics easy to understand and always encourages discussion.'},
#  {'professor': 'Professor John Smith',
#   'subject': 'Physics I',
#   'stars': 4,
#   'review': 'Good professor with clear explanations. The labs are a bit time-consuming, but overall a solid class.'},
#  {'professor': 'Dr. Karen Williams',
#   'subject': 'American Literature',
#   'stars': 3,
#   'review': 'The reading load is heavy, and Dr. Williams expects a lot from students. Be ready to work.'},
#  {'professor': 'Professor David Brown',
#   'subject': 'Macroeconomics',
#   'stars': 5,
#   'review': 'Professor Brown is the best! His lectures are interesting, and he’s always available to help outside of class.'},
#  {'professor': 'Dr. Jessica Taylor',
#   'subject': 'Biology 101',
#   'stars': 4,
#   'review': 'Dr. Taylor is great at explaining difficult concepts. The exams are fair but require thorough preparation.'},
#  {'professor': 'Professor Thomas Anderson',
#   'subject': 'Philosophy 101',
#   'stars': 3,
#   'review': 'The material is interesting, but Professor Anderson can be hard to follow at times. The discussions are engaging, though.'},
#  {'professor': 'Dr. Michelle White',
#   'subject': 'Environmental Science',
#   'stars': 5,
#   'review': 'Dr. White is passionate about the subject and it shows in her teaching. Highly recommend taking her class.'},
#  {'professor': 'Professor Robert Green',
#   'subject': 'Statistics',
#   'stars': 4,
#   'review': 'Solid professor who makes a challenging subject manageable. The assignments are tough but fair.'},
#  {'professor': 'Dr. Linda Moore',
#   'subject': 'Human Anatomy',
#   'stars': 3,
#   'review': 'Dr. Moore is knowledgeable, but her lectures can be a bit monotone. The labs are well-organized, though.'},
#  {'professor': 'Professor Kevin Clark',
#   'subject': 'Political Science',
#   'stars': 2,
#   'review': 'Not a fan of Professor Clark’s teaching style. The lectures feel rushed and not very engaging.'},
#  {'professor': 'Dr. Amy Nelson',
#   'subject': 'Microeconomics',
#   'stars': 5,
#   'review': 'Dr. Nelson is fantastic! She’s clear, concise, and makes sure everyone understands the material.'},
#  {'professor': 'Professor Brian Edwards',
#   'subject': 'Computer Science 101',
#   'stars': 4,
#   'review': 'Professor Edwards is very knowledgeable, and his assignments are challenging but rewarding.'},
#  {'professor': 'Dr. Rachel King',
#   'subject': 'Art History',
#   'stars': 5,
#   'review': 'Dr. King is wonderful! Her passion for art is contagious, and her lectures are a joy to attend.'},
#  {'professor': 'Professor Eric Hall',
#   'subject': 'Introduction to Philosophy',
#   'stars': 3,
#   'review': 'Interesting material, but Professor Hall’s grading can be harsh. Be prepared to defend your arguments.'},
#  {'professor': 'Dr. Olivia Baker',
#   'subject': 'Chemistry 101',
#   'stars': 4,
#   'review': 'Dr. Baker is very approachable and helpful. The class is tough, but she does a great job explaining everything.'},
#  {'professor': 'Professor William Carter',
#   'subject': 'English Composition',
#   'stars': 2,
#   'review': 'Not my favorite class. Professor Carter’s feedback is vague, and the assignments feel a bit repetitive.'}]

# %%
processed_data = []
# Load the pretrained model
model= SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Create embeddings (numerical sematic relationship of words)

for review in data["reviews"]:
    embedding = model.encode(review['review'])


    processed_data.append({
        "values": embedding.tolist(),
        "id": review["professor"],
        "metadata":{
            "review": review["review"],
            "subject": review["subject"],
            "stars": review["stars"]
        }
    })

    print (processed_data)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[8], line 7
#       4 # Create embeddings (numerical sematic relationship of words)
#       6 for review in data["reviews"]:
# ----> 7     response = client.embeddings.create(
#       8         input = review['review'],
#       9         model ='distilbert-base-uncased',
#      10     )
#      11     embedding = response.data[0].embedding
#      12     processed_data.append({
#      13         "values": embedding,
#      14         "id": review["professor"],
#    (...)
#      19         }
#      20     })
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/groq/resources/embeddings.py:79, in Embeddings.create(self, input, model, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#      41 def create(
#      42     self,
#      43     *,
#    (...)
#      53     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#      54 ) -> CreateEmbeddingResponse:
#      55     """
#      56     Creates an embedding vector representing the input text.
#      57
#    (...)
#      77       timeout: Override the client-level default timeout for this request, in seconds
#      78     """
# ---> 79     return self._post(
#      80         "/openai/v1/embeddings",
#      81         body=maybe_transform(
#      82             {
#      83                 "input": input,
#      84                 "model": model,
#      85                 "encoding_format": encoding_format,
#      86                 "user": user,
#      87             },
#      88             embedding_create_params.EmbeddingCreateParams,
#      89         ),
#      90         options=make_request_options(
#      91             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#      92         ),
#      93         cast_to=CreateEmbeddingResponse,
#      94     )
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/groq/_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)
#    1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/groq/_base_client.py:920, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     911 def request(
#     912     self,
#     913     cast_to: Type[ResponseT],
#    (...)
#     918     stream_cls: type[_StreamT] | None = None,
#     919 ) -> ResponseT | _StreamT:
# --> 920     return self._request(
#     921         cast_to=cast_to,
#     922         options=options,
#     923         stream=stream,
#     924         stream_cls=stream_cls,
#     925         remaining_retries=remaining_retries,
#     926     )
#
# File /opt/anaconda3/envs/rag/lib/python3.10/site-packages/groq/_base_client.py:1018, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1015         err.response.read()
#    1017     log.debug("Re-raising status error")
# -> 1018     raise self._make_status_error_from_response(err.response) from None
#    1020 return self._process_response(
#    1021     cast_to=cast_to,
#    1022     options=options,
#    (...)
#    1025     stream_cls=stream_cls,
#    1026 )
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `distilbert-base-uncased` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'code': 'model_not_found'}}

# %%
# Out:
#   Cell In[9], line 1
#     pip install transformers requests
#         ^
# SyntaxError: invalid syntax
